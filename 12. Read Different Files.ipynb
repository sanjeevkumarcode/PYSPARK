# %%
 # %sql
create database development.data

# %%
# %sql
create volume development.data.files

# %% [markdown]
# # **DATAFRAME PRACTICAL**

# %%
df = spark.read.csv('/Volumes/development/data/files/orders/orders.csv')
df.display()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.show()
# Out:
# +------------+--------------------+-----------+----------+-------------+----------+--------+
# |         _c0|                 _c1|        _c2|       _c3|          _c4|       _c5|     _c6|
# +------------+--------------------+-----------+----------+-------------+----------+--------+
# |Project Name|           Task Name|Assigned to|Start Date|Days Required|  End Date|Progress|
# |   Marketing|     Market Research|      Alice|01-01-2024|           13|14-01-2024|     78%|
# |   Marketing|    Content Creation|        Bob|14-01-2024|           14|28-01-2024|    100%|
# |   Marketing|Social Media Plan...|    Charlie|28-01-2024|           22|19-02-2024|     45%|
# |   Marketing|   Campaign Analysis|      Daisy|18-02-2024|           25|14-03-2024|      0%|
# | Product Dev|Prototype Develop...|      Ethan|02-01-2024|           18|20-01-2024|    100%|
# | Product Dev|   Quality Assurance|      Fiona|20-01-2024|           10|30-01-2024|     78%|
# ...

# %%
df = spark.read.csv('/Volumes/development/data/files/orders/orders.csv', header = 'True')
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- Project Name: string (nullable = true)
#  |-- Task Name: string (nullable = true)
#  |-- Assigned to: string (nullable = true)
#  |-- Start Date: string (nullable = true)
#  |-- Days Required: string (nullable = true)
#  |-- End Date: string (nullable = true)
#  |-- Progress: string (nullable = true)

# %%
df1 = spark.read.format("csv").options(header = 'True', inferSchema = 'True').load('/Volumes/development/data/files/orders/orders.csv')
display(df1)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# # **JSON & **PARQUET****

# %%
df = spark.read.json("/Volumes/development/data/files/orders/house-price-parquet (1).json")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df = spark.read.format("json").options(header = 'True').load("/Volumes/development/data/files/orders/house-price-parquet (1).json")
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- airconditioning: string (nullable = true)
#  |-- area: string (nullable = true)
#  |-- basement: string (nullable = true)
#  |-- bathrooms: string (nullable = true)
#  |-- bedrooms: string (nullable = true)
#  |-- furnishingstatus: string (nullable = true)
#  |-- guestroom: string (nullable = true)
#  |-- hotwaterheating: string (nullable = true)
#  |-- mainroad: string (nullable = true)
#  |-- parking: string (nullable = true)
#  |-- prefarea: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- stories: string (nullable = true)

# %%
df = spark.read.parquet("/Volumes/development/data/files/orders/house-price.parquet", header = 'True')
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...
